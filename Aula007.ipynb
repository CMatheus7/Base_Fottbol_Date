# %% [markdown]
# ### Importando Bibliotecas ###

# %%
# !pip install qgrid
# Out:
# ...
# WARNING: Ignoring invalid distribution ~elenium (C:\Users\Home\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~elenium (C:\Users\Home\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~elenium (C:\Users\Home\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
import pandas as pd

# %% [markdown]
# ### Coletando as planilhas das ligas Principais  ###

# %%
# Inglaterra 1

ENG1_13 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/E0.csv') # Campeonato Inglês 2023/2024
ENG1_12 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/E0.csv') # Campeonato Inglês 2023/2024
ENG1_11 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2223/E0.csv') # Campeonato Inglês 2024/2025
ENG1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/E0.csv") # Campeonato Inglês 2021/2022
ENG1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/E0.csv") # Campeonato Inglês 2020/2021
ENG1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/E0.csv") # Campeonato Inglês 2019/2020
ENG1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/E0.csv") # Campeonato Inglês 2018/2019
ENG1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/E0.csv") # Campeonato Inglês 2017/2018
ENG1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/E0.csv") # Campeonato Inglês 2016/2017
ENG1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/E0.csv") # Campeonato Inglês 2015/2016
ENG1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/E0.csv") # Campeonato Inglês 2014/2015
ENG1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/E0.csv") # Campeonato Inglês 2013/2014
ENG1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/E0.csv") # Campeonato Inglês 2012/2013

ENG1 = [ENG1_01,ENG1_02,ENG1_03,ENG1_04,ENG1_05,ENG1_06,ENG1_07,ENG1_08,ENG1_09,ENG1_10, ENG1_11, ENG1_12, ENG1_13]
ENG1 = pd.concat(ENG1)
ENG1['Liga'] = 'Inglaterra 1'

# Inglaterra 2

ENG2_13 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/E1.csv') # Campeonato Inglês 2023/2024
ENG2_12 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/E1.csv') # Campeonato Inglês 2023/2024
ENG2_11 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2223/E1.csv') # Campeonato Inglês 2024/2025
ENG2_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/E1.csv") # Campeonato Inglês 2021/2022
ENG2_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/E1.csv") # Campeonato Inglês 2020/2021
ENG2_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/E1.csv") # Campeonato Inglês 2019/2020
ENG2_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/E1.csv") # Campeonato Inglês 2018/2019
ENG2_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/E1.csv") # Campeonato Inglês 2017/2018
ENG2_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/E1.csv") # Campeonato Inglês 2016/2017
ENG2_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/E1.csv") # Campeonato Inglês 2015/2016
ENG2_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/E1.csv") # Campeonato Inglês 2014/2015
ENG2_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/E1.csv") # Campeonato Inglês 2013/2014
ENG2_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/E1.csv") # Campeonato Inglês 2012/2013

ENG2 = [ENG2_01,ENG2_02,ENG2_03,ENG2_04,ENG2_05,ENG2_06,ENG2_07,ENG2_08,ENG2_09,ENG2_10, ENG2_11, ENG2_12, ENG2_13]
ENG2 = pd.concat(ENG2)
ENG2['Liga'] = 'Inglaterra 2'


# Alemanha 1

GER1_13 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/D1.csv')
GER1_12 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/D1.csv')
GER1_11 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2223/D1.csv')
GER1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/D1.csv")
GER1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/D1.csv")
GER1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/D1.csv")
GER1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/D1.csv")
GER1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/D1.csv")
GER1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/D1.csv")
GER1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/D1.csv")
GER1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/D1.csv")
GER1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/D1.csv")
GER1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/D1.csv")
GER1 = [GER1_01,GER1_02,GER1_03,GER1_04,GER1_05,GER1_06,GER1_07,GER1_08,GER1_09,GER1_10, GER1_11, GER1_12, GER1_13]
GER1 = pd.concat(GER1)
GER1['Liga'] = 'Alemanha 1'

# Alemanha 2

GER2_13 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/D2.csv')
GER2_12 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/D2.csv')
GER2_11 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2223/D2.csv')
GER2_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/D2.csv")
GER2_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/D2.csv")
GER2_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/D2.csv")
GER2_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/D2.csv")
GER2_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/D2.csv")
GER2_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/D2.csv")
GER2_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/D2.csv")
GER2_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/D2.csv")
GER2_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/D2.csv")
GER2_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/D2.csv")
GER2 = [GER2_01,GER2_02,GER2_03,GER2_04,GER2_05,GER2_06,GER2_07,GER2_08,GER2_09,GER2_10, GER2_11, GER2_12, GER2_13]
GER2 = pd.concat(GER2)
GER2['Liga'] = 'Alemanha 2'

# Itália 1

ITA1_13 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/I1.csv')
ITA1_12 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/I1.csv')
ITA1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/I1.csv")
ITA1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/I1.csv")
ITA1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/I1.csv")
ITA1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/I1.csv")
ITA1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/I1.csv")
ITA1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/I1.csv")
ITA1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/I1.csv")
ITA1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/I1.csv")
ITA1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/I1.csv")
ITA1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/I1.csv")
ITA1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/I1.csv")
ITA1 = [ITA1_01,ITA1_02,ITA1_03,ITA1_04,ITA1_05,ITA1_06,ITA1_07,ITA1_08,ITA1_09,ITA1_10, ITA1_11, ITA1_12, ITA1_13]
ITA1 = pd.concat(ITA1)
ITA1['Liga'] = 'Itália 1'

# Itália 2

ITA2_13 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/I2.csv')
ITA2_12 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/I2.csv')
ITA2_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/I2.csv")
ITA2_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/I2.csv")
ITA2_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/I2.csv")
ITA2_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/I2.csv")
# ITA2_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/I2.csv")
ITA2_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/I2.csv")
ITA2_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/I2.csv")
ITA2_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/I2.csv")
ITA2_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/I2.csv")
ITA2_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/I2.csv")
ITA2_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/I2.csv")
ITA2 = [ITA2_01,ITA2_02,ITA2_03,ITA2_05,ITA2_06,ITA2_08,ITA2_09,ITA2_10, ITA2_11, ITA2_12, ITA2_13]
ITA2 = pd.concat(ITA2)
ITA2['Liga'] = 'Itália 2'

# Espanha 1

SPA1_13 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/SP1.csv')
SPA1_12 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/SP1.csv')
SPA1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/SP1.csv")
SPA1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/SP1.csv")
SPA1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/SP1.csv")
SPA1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/SP1.csv")
SPA1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/SP1.csv")
SPA1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/SP1.csv")
SPA1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/SP1.csv")
SPA1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/SP1.csv")
SPA1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/SP1.csv")
SPA1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/SP1.csv")
SPA1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/SP1.csv")
SPA1 = [SPA1_01,SPA1_02,SPA1_03,SPA1_04,SPA1_05,SPA1_06,SPA1_07,SPA1_08,SPA1_09,SPA1_10, SPA1_11, SPA1_12, SPA1_13]
SPA1 = pd.concat(SPA1)
SPA1['Liga'] = 'Espanha 1'

# Espanha 2
SPA2_13 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/SP2.csv')
SPA2_12 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/SP2.csv')
SPA2_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/SP2.csv")
SPA2_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/SP2.csv")
SPA2_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/SP2.csv")
SPA2_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/SP2.csv")
SPA2_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/SP2.csv")
SPA2_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/SP2.csv")
SPA2_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/SP2.csv")
SPA2_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/SP2.csv")
SPA2_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/SP2.csv")
SPA2_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/SP2.csv")
SPA2_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/SP2.csv")
SPA2 = [SPA2_01,SPA2_02,SPA2_03,SPA2_04,SPA2_05,SPA2_06,SPA2_07,SPA2_08,SPA2_09,SPA2_10, SPA2_11, SPA2_12, SPA2_13]
SPA2 = pd.concat(SPA2)
SPA2['Liga'] = 'Espanha 2'

# França 1
FRA1_13 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/F1.csv")
FRA1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/F1.csv")
FRA1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/F1.csv")
FRA1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/F1.csv")
FRA1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/F1.csv")
FRA1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/F1.csv")
FRA1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/F1.csv")
FRA1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/F1.csv")
FRA1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/F1.csv")
FRA1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/F1.csv")
FRA1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/F1.csv")
FRA1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/F1.csv")
FRA1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/F1.csv")
FRA1 = [FRA1_01,FRA1_02,FRA1_03,FRA1_04,FRA1_05,FRA1_06,FRA1_07,FRA1_08,FRA1_09,FRA1_10, FRA1_11, FRA1_12, FRA1_13]
FRA1 = pd.concat(FRA1)
FRA1['Liga'] = 'França 1'

# França 2
FRA2_13 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/F2.csv")
FRA2_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/F2.csv")
FRA2_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/F2.csv")
FRA2_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/F2.csv")
FRA2_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/F2.csv")
FRA2_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/F2.csv")
FRA2_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/F2.csv")
FRA2_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/F2.csv")
FRA2_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/F2.csv")
FRA2_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/F2.csv")
FRA2_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/F2.csv")
FRA2_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/F2.csv")
FRA2_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/F2.csv")
FRA2 = [FRA2_01,FRA2_02,FRA2_03,FRA2_04,FRA2_05,FRA2_06,FRA2_07,FRA2_08,FRA2_09,FRA2_10, FRA2_11, FRA2_12, FRA2_13]
FRA2 = pd.concat(FRA2)
FRA2['Liga'] = 'França 2'

# Holanda 1
NET1_13 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/N1.csv")
NET1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/N1.csv")
NET1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/N1.csv")
NET1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/N1.csv")
NET1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/N1.csv")
NET1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/N1.csv")
NET1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/N1.csv")
NET1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/N1.csv")
NET1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/N1.csv")
NET1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/N1.csv")
NET1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/N1.csv")
NET1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/N1.csv")
NET1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/N1.csv")
NET1 = [NET1_01,NET1_02,NET1_03,NET1_04,NET1_05,NET1_06,NET1_07,NET1_08,NET1_09,NET1_10, NET1_11, NET1_12, NET1_13]
NET1 = pd.concat(NET1)
NET1['Liga'] = 'Holanda 1'

# Bélgica 1
BEL1_13 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/B1.csv")
BEL1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/B1.csv")
BEL1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/B1.csv")
BEL1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/B1.csv")
BEL1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/B1.csv")
BEL1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/B1.csv")
BEL1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/B1.csv")
BEL1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/B1.csv")
BEL1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/B1.csv")
BEL1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/B1.csv")
BEL1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/B1.csv")
BEL1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/B1.csv")
BEL1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/B1.csv")
BEL1 = [BEL1_01,BEL1_02,BEL1_03,BEL1_04,BEL1_05,BEL1_06,BEL1_07,BEL1_08,BEL1_09,BEL1_10, BEL1_11, BEL1_12, BEL1_13]
BEL1 = pd.concat(BEL1)
BEL1['Liga'] = 'Bélgica 1'

# Portugal 1
POR1_13 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/P1.csv")
POR1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/P1.csv")
POR1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/P1.csv")
POR1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/P1.csv")
POR1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/P1.csv")
POR1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/P1.csv")
POR1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/P1.csv")
POR1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/P1.csv")
POR1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/P1.csv")
POR1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/P1.csv")
POR1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/P1.csv")
POR1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/P1.csv")
POR1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/P1.csv")
POR1 = [POR1_01,POR1_02,POR1_03,POR1_04,POR1_05,POR1_06,POR1_07,POR1_08,POR1_09,POR1_10, POR1_11, POR1_12, POR1_13]
POR1 = pd.concat(POR1)
POR1['Liga'] = 'Portugal 1'

# Turquia 1
TUR1_13 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/T1.csv")
TUR1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/T1.csv")
TUR1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/T1.csv")
TUR1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/T1.csv")
TUR1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/T1.csv")
TUR1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/T1.csv")
TUR1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/T1.csv")
TUR1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/T1.csv")
TUR1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/T1.csv")
TUR1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/T1.csv")
TUR1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/T1.csv")
TUR1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/T1.csv")
TUR1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/T1.csv")
TUR1 = [TUR1_01,TUR1_02,TUR1_03,TUR1_04,TUR1_05,TUR1_06,TUR1_07,TUR1_08,TUR1_09,TUR1_10,TUR1_11,TUR1_12,TUR1_13]
TUR1 = pd.concat(TUR1)
TUR1['Liga'] = 'Turquia 1'
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_7240\1881873980.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ENG1['Liga'] = 'Inglaterra 1'
# C:\Users\Home\AppData\Local\Temp\ipykernel_7240\1881873980.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ENG2['Liga'] = 'Inglaterra 2'
# ...

# %%
# Concatenando as Planilhas
df = [ENG1, ENG2,GER1, GER2, ITA1, ITA2, SPA1, SPA2, FRA1, FRA2, NET1, BEL1, POR1, TUR1]
df = pd.concat(df)

# %%
# Selecionando e Renomeando as Colunas
df = df[['Liga','Date','HomeTeam','AwayTeam','HTHG','HTAG','HTR','FTHG','FTAG','FTR','B365H','B365D','B365A','B365>2.5']]
df.columns = ['League','Date','Home','Away','Goals_H_HT','Goals_A_HT','Result_HT','Goals_H_FT','Goals_A_FT','Result_FT','Odds_H','Odds_D','Odds_A','Odds_Over25_FT']

# Ajustando o Índice do DataFrame
df.reset_index(inplace=True, drop=True)
df.index = df.index.set_names(['Nº'])
df = df.rename(index=lambda x: x + 1)
df = df.dropna()
df.to_excel('Base_FootBall_Data.xlsx')

# %%
# Dados de Pontos

def Pontos_H (Result_FT):
    if Result_FT == 'H':
        Pontos = 3
    elif Result_FT == 'D':
        Pontos = 1
    else:
        Pontos = 0
    return Pontos

def Pontos_A (Result_FT):
    if Result_FT == 'A':
        Pontos = 3
    elif Result_FT == 'D':
        Pontos = 1
    else:
        Pontos = 0
    return Pontos

df['Pontos_H'] = df.apply(lambda row: Pontos_H(row['Result_FT']), axis=1)

df['Pontos_A'] = df.apply(lambda row: Pontos_A(row['Result_FT']), axis=1)

# %%
# Dados de Gols

df['Total_Goals_HT'] = df.apply(lambda row: (row['Goals_H_HT'] + row['Goals_A_HT']), axis=1) 

df['Total_Goals_FT'] = df.apply(lambda row: (row['Goals_H_FT'] + row['Goals_A_FT']), axis=1) 

df['Over05_HT'] = df.apply(lambda row: 1 if (row['Total_Goals_HT'] > 0) else 0, axis=1) 

df['Over05_FT'] = df.apply(lambda row: 1 if (row['Total_Goals_FT'] > 0) else 0, axis=1) 

df['Over15_FT'] = df.apply(lambda row: 1 if (row['Total_Goals_FT'] > 1) else 0, axis=1) 

df['Over25_FT'] = df.apply(lambda row: 1 if (row['Total_Goals_FT'] > 2) else 0, axis=1) 

df['BTTS'] = df.apply(lambda row: 1 if (row['Goals_H_FT'] > 0 and row['Goals_A_FT'] > 0) else 0, axis=1)

# %% [markdown]
# Coletando as planilhas das Ligas Secundárias

# %%
# Porcentagens

df['Porc_Over05HT_Home'] = (df.groupby('Home')['Over05_HT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)
df['Porc_Over05HT_Away'] = (df.groupby('Away')['Over05_HT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)

df['Porc_Over05FT_Home'] = (df.groupby('Home')['Over05_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)
df['Porc_Over05FT_Away'] = (df.groupby('Away')['Over05_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)

df['Porc_Over15FT_Home'] = (df.groupby('Home')['Over15_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)
df['Porc_Over15FT_Away'] = (df.groupby('Away')['Over15_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)

df['Porc_Over25FT_Home'] = (df.groupby('Home')['Over25_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)
df['Porc_Over25FT_Away'] = (df.groupby('Away')['Over25_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)

df['Porc_BTTS_Home'] = (df.groupby('Home')['BTTS'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)
df['Porc_BTTS_Away'] = (df.groupby('Away')['BTTS'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)

# %% [markdown]
# Concatenando as Planilhas

# %%
# Estatísticas de Pontos

# Média
df['Media_Pontos_H'] = df.groupby('Home')['Pontos_H'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True)
df['Media_Pontos_A'] = df.groupby('Away')['Pontos_A'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True)

# Desvio Padrão
df['DP_Pontos_H'] = df.groupby('Home')['Pontos_H'].rolling(window=5, min_periods=1).std().reset_index(0,drop=True)
df['DP_Pontos_A'] = df.groupby('Away')['Pontos_A'].rolling(window=5, min_periods=1).std().reset_index(0,drop=True)

# Coeficiente de Variação
df['CV_Pontos_H'] = df['DP_Pontos_H'] / df['Media_Pontos_H']
df['CV_Pontos_A'] = df['DP_Pontos_A'] / df['Media_Pontos_A']

# %%
# Estatísticas de Gols

# Média
df['Media_Gols_Feitos_Home'] = df.groupby('Home')['Goals_H_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True)
df['Media_Gols_Sofridos_Home'] = df.groupby('Home')['Goals_A_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True)

df['Media_Gols_Feitos_Away'] = df.groupby('Away')['Goals_A_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True)
df['Media_Gols_Sofridos_Away'] = df.groupby('Away')['Goals_H_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True)

# Desvio Padrão
df['DP_Gols_Feitos_Home'] = df.groupby('Home')['Goals_H_FT'].rolling(window=5, min_periods=1).std().reset_index(0,drop=True)
df['DP_Gols_Sofridos_Home'] = df.groupby('Home')['Goals_A_FT'].rolling(window=5, min_periods=1).std().reset_index(0,drop=True)

df['DP_Gols_Feitos_Away'] = df.groupby('Away')['Goals_A_FT'].rolling(window=5, min_periods=1).std().reset_index(0,drop=True)
df['DP_Gols_Sofridos_Away'] = df.groupby('Away')['Goals_H_FT'].rolling(window=5, min_periods=1).std().reset_index(0,drop=True)

# Coeficiente de Variação
df['CV_Gols_Feitos_Home'] = (df['DP_Gols_Feitos_Home'] / df['Media_Gols_Feitos_Home'])
df['CV_Gols_Sofridos_Home'] = (df['DP_Gols_Sofridos_Home'] / df['Media_Gols_Sofridos_Home'])

df['CV_Gols_Feitos_Away'] = (df['DP_Gols_Feitos_Away'] / df['Media_Gols_Feitos_Away'])
df['CV_Gols_Sofridos_Away'] = (df['DP_Gols_Sofridos_Away'] / df['Media_Gols_Sofridos_Away'])

# %%
# Probabilidades
df['p(H)'] = df.apply(lambda row: (1/ row['Odds_H']), axis=1)
df['p(D)'] = df.apply(lambda row: (1/ row['Odds_D']), axis=1)
df['p(A)'] = df.apply(lambda row: (1/ row['Odds_A']), axis=1)

# %% [markdown]
# Visualizando o Resultado Final

# %%
df
# Out:
#              League        Date            Home              Away  Goals_H_HT  \
# Nº
# 2662   Inglaterra 1  09/08/2019       Liverpool           Norwich         4.0
# 2663   Inglaterra 1  10/08/2019        West Ham          Man City         0.0
# 2664   Inglaterra 1  10/08/2019     Bournemouth  Sheffield United         0.0
# 2665   Inglaterra 1  10/08/2019         Burnley       Southampton         0.0
# 2666   Inglaterra 1  10/08/2019  Crystal Palace           Everton         0.0
# ...             ...         ...             ...               ...         ...
# 62577     Turquia 1  09/11/2024        Rizespor       Trabzonspor         1.0
# 62578     Turquia 1  10/11/2024          Goztep         Konyaspor         0.0
# 62579     Turquia 1  10/11/2024     Galatasaray        Samsunspor         1.0
# 62580     Turquia 1  10/11/2024      Buyuksehyr          Besiktas         0.0
# 62581     Turquia 1  10/11/2024      Fenerbahce         Sivasspor         1.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27875 entries, 2662 to 62581
# Data columns (total 54 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   League                    27875 non-null  object
#  1   Date                      27875 non-null  object
#  2   Home                      27875 non-null  object
#  3   Away                      27875 non-null  object
#  4   Goals_H_HT                27875 non-null  float64
#  5   Goals_A_HT                27875 non-null  float64
#  6   Result_HT                 27875 non-null  object
#  7   Goals_H_FT                27875 non-null  float64
#  8   Goals_A_FT                27875 non-null  float64
#  9   Result_FT                 27875 non-null  object
#  10  Odds_H                    27875 non-null  float64
#  11  Odds_D                    27875 non-null  float64
#  12  Odds_A                    27875 non-null  float64
# ...

# %%
df.dropna()
# Out:
#              League        Date              Home            Away  Goals_H_HT  \
# Nº
# 2683   Inglaterra 1  24/08/2019           Norwich         Chelsea         2.0
# 2684   Inglaterra 1  24/08/2019          Brighton     Southampton         0.0
# 2685   Inglaterra 1  24/08/2019        Man United  Crystal Palace         0.0
# 2686   Inglaterra 1  24/08/2019  Sheffield United       Leicester         0.0
# 2688   Inglaterra 1  24/08/2019         Liverpool         Arsenal         1.0
# ...             ...         ...               ...             ...         ...
# 62577     Turquia 1  09/11/2024          Rizespor     Trabzonspor         1.0
# 62578     Turquia 1  10/11/2024            Goztep       Konyaspor         0.0
# 62579     Turquia 1  10/11/2024       Galatasaray      Samsunspor         1.0
# 62580     Turquia 1  10/11/2024        Buyuksehyr        Besiktas         0.0
# 62581     Turquia 1  10/11/2024        Fenerbahce       Sivasspor         1.0
#
# ...

# %% [markdown]
# Exportando o arquivo final para o Excel

# %%
df.to_excel("Base_de_Dados_(Variaveis_Secundarias).xlsx")
