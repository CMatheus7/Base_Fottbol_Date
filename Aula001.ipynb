# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://www.football-data.co.uk/mmz4281/1819/I2.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#     Div      Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E1  03/08/13       Barnsley          Wigan     0     4   A     0     1
# 1    E1  03/08/13     Birmingham        Watford     0     1   A     0     1
# 2    E1  03/08/13    Bournemouth       Charlton     2     1   H     1     0
# 3    E1  03/08/13        Burnley         Bolton     1     1   D     1     1
# 4    E1  03/08/13      Doncaster      Blackpool     1     3   A     0     1
# ..   ..       ...            ...            ...   ...   ...  ..   ...   ...
# 547  E1  03/05/14       Millwall    Bournemouth     1     0   H     1     0
# 548  E1  03/05/14  Nott'm Forest       Brighton     1     2   A     1     0
# 549  E1  03/05/14        Reading        Burnley     2     2   D     1     2
# 550  E1  03/05/14        Watford   Huddersfield     1     4   A     0     0
# 551  E1  03/05/14         Yeovil  Middlesbrough     1     4   A     1     3
#
# ...

# %%
df = df [['Date','HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR','B365H', 'B365D', 'B365A']]

# %%
df.columns = ['Data','Mandante', 'Visitante', 'Gols_Mandande', 'Gols_Visitante', 'Resultado', 'Odds_Mandante', 'Odds_Empate', 'Odds_Visitante']

# %%
df
# Out:
#          Data       Mandante      Visitante  Gols_Mandande  Gols_Visitante  \
# 0    03/08/13       Barnsley          Wigan              0               4
# 1    03/08/13     Birmingham        Watford              0               1
# 2    03/08/13    Bournemouth       Charlton              2               1
# 3    03/08/13        Burnley         Bolton              1               1
# 4    03/08/13      Doncaster      Blackpool              1               3
# ..        ...            ...            ...            ...             ...
# 547  03/05/14       Millwall    Bournemouth              1               0
# 548  03/05/14  Nott'm Forest       Brighton              1               2
# 549  03/05/14        Reading        Burnley              2               2
# 550  03/05/14        Watford   Huddersfield              1               4
# 551  03/05/14         Yeovil  Middlesbrough              1               4
#
#     Resultado  Odds_Mandante  Odds_Empate  Odds_Visitante
# ...

# %%
#df.to_excel('C:/Users/Home/Documents/certificadobetfair - CM/Base_Fotball-Date/Analise.xlsx', index=False)
